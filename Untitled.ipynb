# %% [markdown]
# # Set random_sample to True if you'd like random dialogues converted to pirate_tongue. For a fixed sample, set random_sample to False

# %%
random_sample = False

# %%
import random
from translate_module import translate_to_pirate as pirate_bot

# %%
f = open('movie_lines.txt','r')
content = f.readlines()
f.close()

# %%
if random_sample == True:
    chosen_sample = random.sample(content,51)
else:
    chosen_ids = list(range(0,len(content),int(len(content)/50)))
    chosen_sampel = [content[i] for i in chosen_ids]

for c in chosen_sample:
    c = c.rstrip()
    print("Actual:",c)
    translation = pirate_bot(c)
    print("Pirate:",translation)
    print('\n\n')
# Out:
# Actual: All visitors to the coast.
# Pirate: Scupper that!all visitors t' the coast.
#
#
#
# Actual: I feel this may be a trick.
# Pirate: Arr!i feel this may be a trick.
#
#
#
# Actual: There's a sail locker under the wheel deck.
# Pirate: Aaarrghhhh!there's a sail locker under the wheel deck.
#
#
#
# Actual: I will.
# Pirate: Avast Ye!i will.
#
#
#
# Actual: One of you is mighty handy with a knife.
# Pirate: Avast Ye!one of ye is mighty handy with a knife.
#
#
#
# Actual: Edward, fuck her now!
# Pirate: Arr!edward, fuck her now!
#
#
#
# Actual: That's during the daytime, of course.
# Pirate: Blow Me Down!that's during the daytime, of course.
#
#
#
# Actual: All right, walk him down.
# Pirate: Blimey!all right, walk him down.
#
#
#
# Actual: I should have stayed on the plantation ... ...helping run it.
# Pirate: Well shave me belly with a rusty razor!i should have stayed on the plantation ... ...helping run it.
#
#
#
# Actual: No, I didn't.
# Pirate: Sink me!no, i didn't.
#
#
#
# Actual: All your deeds laid bare.
# Pirate: Alas!all yer deeds laid bare.
#
#
#
# Actual: That's fine, Jim.
# Pirate: Shiver me timbers!that's fine, jim.
#
#
#
# Actual: Bottle of rum!
# Pirate: Shiver me timbers!bottle of rum!
#
#
#
# Actual: Is that so?
# Pirate: Blimey!is that so?
#
#
#
# Actual: Here, lad.
# Pirate: Well shave me belly with a rusty razor!here, lad.
#
#
#
# Actual: And all your treasure will come back to you.
# Pirate: Aaarrghhhh!and all yer booty will come aft t' ye.
#
#
#
# Actual: You'll be needing it.
# Pirate: Sink me!you'll be needin' it.
#
#
#
# Actual: I don't think they intend to demonstrate against Baron Gruda after all.
# Pirate: Well shave me belly with a rusty razor!i don't think they intend t' demonstrate against baron gruda after all.
#
#
#
# Actual: Your cabin door's been locked so long, l thought you'd thrown away the key.
# Pirate: Alas!your cabin door's been locked so long, l thought ye'd thrown away the key.
#
#
#
# Actual: Do you have a plan?
# Pirate: Arr!do ye have a plan?
#
#
#
# Actual: The lair of the dragon.
# Pirate: Scupper that!the lair of the dragon.
#
#
#
# Actual: And he can stay there.
# Pirate: Yo Ho Ho!and he can stay thar.
#
#
#
# Actual: Ship?
# Pirate: Well shave me belly with a rusty razor!ship?
#
#
#
# Actual: Your father, what was his name?
# Pirate: Shiver me timbers!your father, what was his name?
#
#
#
# Actual: Aye, aye, Sir.
# Pirate: Arr!aye, aye, sir.
#
#
#
# Actual: I like that!
# Pirate: Arr!i like that!
#
#
#
# Actual: March!
# Pirate: Yo Ho Ho!march!
#
#
#
# Actual: Professor Prudence.
# Pirate: Blimey!professor prudence.
#
#
#
# Actual: Aye.
# Pirate: Aaarrghhhh!aye.
#
#
#
# Actual: You won't steal?
# Pirate: Shiver me timbers!you won't pillage?
#
#
#
# Actual: What were you doing?
# Pirate: Sink me!what were ye doing?
#
#
#
# Actual: Carina Smyth.
# Pirate: Scupper that!carina smyth.
#
#
#
# Actual: I can not go into the captain's chambers without permission, sir.
# Pirate: Scupper that!i can not go into the cap'n's chambers without permission, sir.
#
#
#
# Actual: If I could get that room now, please?
# Pirate: Blow Me Down!if i could get that room now, please?
#
#
#
# Actual: Sir, it's a miracle she missed them!
# Pirate: Alas!sir, it's a miracle she missed them!
#
#
#
# Actual: He chose to stand between Jim and death on two occasions.
# Pirate: Well shave me belly with a rusty razor!he chose t' stand between jim an' davy jones' locker on two occasions.
#
#
#
# Actual: Destination Poole.
# Pirate: Arr!destination poole.
#
#
#
# Actual: I'll feed the men, sir.
# Pirate: Scupper that!i'll feed the men, sir.
#
#
#
# Actual: Get the chest!
# Pirate: Blow Me Down!get the chest!
#
#
#
# Actual: You may kiss the bride.
# Pirate: Scupper that!you may kiss the bride.
#
#
#
# Actual: Now, question.
# Pirate: Me eyes must be foolin' me!now, question.
#
#
#
# Actual: But if we don't, we'll never fully understand what it's capable of.
# Pirate: Blimey!but if we don't, we'll  ne'e'r fully savvy what it's capable of.
#
#
#
# Actual: I may just take you up on that, Dessa.
# Pirate: Scupper that!i may just take ye up on that, dessa.
#
#
#
# Actual: You want your lives, that's yours.
# Pirate: Blow Me Down!you have a fierce fire in me belly for yer lives, that's yers.
#
#
#
# Actual: My lady.
# Pirate: Me eyes must be foolin' me!my lady.
#
#
#
# Actual: Yeah!
# Pirate: Blow Me Down!yeah!
#
#
#
# Actual: Read it for yourself.
# Pirate: Aaarrghhhh!read it fer yerself.
#
#
#
# Actual: I'm sorry, but it's such a pretty boat.
# Pirate: Arr!i'm sorry, but it's such a proud schooner.
#
#
#
# Actual: Worthy of respect.
# Pirate: Avast Ye!worthy of respect.
#
#
#
# Actual: Open it up!
# Pirate: Alas!open it up!
#
#
#
# Actual: It was Ketch who told me of certain activities... he knew were going on here in Dymchurch.
# Pirate: Me eyes must be foolin' me!it was ketch who t'ld me of certain activities... he knew were goin' on here in dymchurch.

# %% [markdown]
# # Fun quotes converted into pirate tongue

# %%
test_str = "The world is not what it used to be. It mean the world to her, it's nothing but a nut to me"

# %%
pirate_bot(test_str)
# Out:
# "Shiver me timbers!the world is not what it used t' be. it mean the world t' her, it's nothin' but a nut t' me"

# %%
pirate_bot("Proceed to the next level, 'bout the base, no treble")
# Out:
# "Yo Ho Ho!proceed t' the next level, 'bout the base, no treble"

# %% [markdown]
# # Funny ones from pirate movie lines converted into pirate tongue
#
# <b>All part of the plan, yeah?</b><br>
# Shiver me timbers!all part of the plan, aye ?
#
# <b>I'm so ready to be married. </b><br>
# Aaarrghhhh!i'm so ready t' be married
#
# <b>As for Treasure Island, the bar silver lies there still... ... but wild horses couldn't drive me back to that accursed place.</b><br>
# Well shave me belly with a rusty razor!as fer booty island, the bar silver lies thar still... ... but wild horses couldn't drive me aft t' that accursed place.
#
# <b>USA return to positions.</b><br>
# Arr!usa return t' positions.
#
# <b>A slave? </b><br>
# Shiver me timbers!a slave?
#
# <b>Clear the deck! </b><br>
# Blow Me Down!clear the deck!
#
# <b>It was a deafening nightmare shriek. </b><br>
# Alas!it was a deafenin' nightmare shriek.
