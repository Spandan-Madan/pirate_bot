# %% [markdown]
# # Set random_sample to True if you'd like random dialogues converted to pirate_tongue. For a fixed sample, set random_sample to False

# %%
RANDOM_SAMPLE = True

# %%
import random
from translate_module import translate_to_pirate as pirate_bot

# %%
f = open('data/movie_lines.txt','r')
content = f.readlines()
f.close()

# %%
if RANDOM_SAMPLE == True:
    chosen_sample = random.sample(content,51)
else:
    chosen_ids = list(range(0,len(content),int(len(content)/50)))
    chosen_sampel = [content[i] for i in chosen_ids]

for c in chosen_sample:
    c = c.rstrip()
    print("Actual:",c)
    translation = pirate_bot(c)
    print("Pirate:",translation)
    print('\n\n')
# Out:
# Actual: High up there now!
# Pirate: Scupper that!high up thar now!
#
#
#
# Actual: [Jack] # Yo ho, yo ho A pirate's life for me [humming] # We're devils and black sheep Really bad eggs # Drink up, me hearties Yo ho [boy] # Yo ho, yo ho A pirate's life for me # We pillage, we plunder We rifle and loot # Drink up, me hearties Yo ho # We kidnap and ravage And don't give a hoot # Drink up, me hearties Yo ho # Yo ho, yo ho A pirate's life for me #
# Pirate: Shiver me timbers![jack] # yo ho, yo ho a pirate's life fer me [hummin'] # we're devils an' black sheep really bad eggs # drink up, me hearties yo ho [boy] # yo ho, yo ho a pirate's life fer me # we pillage, we pillage we rifle an' loot # drink up, me hearties yo ho # we kidnap an' ravage an' don't give a hoot # drink up, me hearties yo ho # yo ho, yo ho a pirate's life fer me #
#
#
#
# Actual: Thank you, sirs.
# Pirate: Sink me!thank ye, sirs.
#
#
#
# Actual: Dr. Blyss told me some time ago.
# ...

# %% [markdown]
# # Fun quotes converted into pirate tongue

# %%
pirate_bot("The world is not what it used to be. It mean the world to her, it's nothing but a nut to me")
# Out:
# "Arr!the world is not what it used t' be. it mean the world t' her, it's nothing but a nut t' me"

# %%
pirate_bot("Proceed to the next level, 'bout the base, no treble")
# Out:
# "Blow Me Down!proceed t' the next level, 'bout the base, no treble"

# %% [markdown]
# # Funny ones from pirate movie lines converted into pirate tongue
#
# <b>All part of the plan, yeah?</b><br>
# Shiver me timbers!all part of the plan, aye ?
#
# <b>I'm so ready to be married. </b><br>
# Aaarrghhhh!i'm so ready t' be married
#
# <b>As for Treasure Island, the bar silver lies there still... ... but wild horses couldn't drive me back to that accursed place.</b><br>
# Well shave me belly with a rusty razor!as fer booty island, the bar silver lies thar still... ... but wild horses couldn't drive me aft t' that accursed place.
#
# <b>USA return to positions.</b><br>
# Arr!usa return t' positions.
#
# <b>A slave? </b><br>
# Shiver me timbers!a slave?
#
# <b>Clear the deck! </b><br>
# Blow Me Down!clear the deck!
#
# <b>It was a deafening nightmare shriek. </b><br>
# Alas!it was a deafenin' nightmare shriek.
